# %%
# !git clone https://github.com/ultralytics/yolov5

# %%
# !cd yolov5 & pip install -r requirements.txt

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
import os

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# fatal: destination path 'labelImg' already exists and is not an empty directory.

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd yolov5 && python train.py --img 640 --batch 16 --epochs 250 --data dataset.yml --weights yolov5s.pt --workers 8
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=250, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5
# fatal: cannot change to 'C:\Users\ishan\Desktop\Defect': No such file or directory
# YOLOv5  2023-4-16 Python-3.9.7 torch-1.13.1 CUDA:0 (NVIDIA GeForce RTX 2080 Super, 8192MiB)
#
# ...

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5/runs/train/exp13/weights/best.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\ishan/.cache\torch\hub\master.zip
# YOLOv5  2023-4-17 Python-3.9.7 torch-1.13.1 CUDA:0 (NVIDIA GeForce RTX 2080 Super, 8192MiB)
# requirements: C:\Users\ishan\.cache\torch\hub\requirements.txt not found, check failed.
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
img = r"C:\Users\ishan\Downloads\TELEVISION NEW\s-l400.jpg"
results = model(img)
results.print()
# Out:
# image 1/1: 300x400 1 broken
# Speed: 9.4ms pre-process, 16.6ms inference, 5.0ms NMS per image at shape (1, 3, 480, 640)

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE" #QUICK FIX TO STOP KERNEL FROM DYING
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
cap = cv2.VideoCapture(2)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Make detections 
    results = model(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
